# %% [markdown]
# # 04. Model Evaluation & Vertex AI Endpoint Deployment
#
# This notebook demonstrates Stages 4 and 5 of `distillfw`:
# - **Stage 4 (`model_evaluator`)**: Computes lexical metrics (BLEU, ROUGE-1/2, Exact Match), LLM-as-a-Judge rubric scores & win rates against Gemini, and latency/cost-savings metrics.
# - **Stage 5 (`model_deployer`)**: Registers the distilled Gemma model in Vertex AI Model Registry with vLLM and deploys to a Vertex AI Endpoint.

# %% [markdown]
# # 04. Model Evaluation & Vertex AI Endpoint Deployment
#
# This notebook demonstrates Stages 4 and 5 of `distillfw`:
# - **Stage 4 (`model_evaluator`)**: Computes lexical metrics (BLEU, ROUGE-1/2, Exact Match), LLM-as-a-Judge rubric scores & win rates against Gemini, and latency/cost-savings metrics.
# - **Stage 5 (`model_deployer`)**: Registers the distilled Gemma model in Vertex AI Model Registry with vLLM and deploys to a Vertex AI Endpoint.

# %%
from distillfw.stages.evaluator import compute_lexical_metrics

teacher_references = [
    "The customer is requesting a refund due to a duplicate billing charge.",
    "Route this ticket to the Tier-2 Networking team for firewall inspection.",
]
distilled_student_predictions = [
    "The customer is requesting a refund due to a duplicate billing charge.",
    "Route ticket to Tier-2 Networking team for firewall inspection.",
]

metrics = compute_lexical_metrics(distilled_student_predictions, teacher_references)
print("Evaluation Lexical Metrics:", metrics)

# %%
from distillfw.stages.evaluator import compute_lexical_metrics

teacher_references = [
    "The customer is requesting a refund due to a duplicate billing charge.",
    "Route this ticket to the Tier-2 Networking team for firewall inspection.",
]
distilled_student_predictions = [
    "The customer is requesting a refund due to a duplicate billing charge.",
    "Route ticket to Tier-2 Networking team for firewall inspection.",
]

metrics = compute_lexical_metrics(distilled_student_predictions, teacher_references)
print("Evaluation Lexical Metrics:", metrics)
